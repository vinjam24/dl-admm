# %%
import torch.nn as nn
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import time
from torch.autograd import Variable
import matplotlib.pyplot as plt

# %%
len_classes = 2
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def get_moon_data(n_samples=1000, noise=0.1):

    X, y = make_moons(n_samples=n_samples, noise=noise, random_state=42)

    # Train test split
    X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    X_train = torch.as_tensor(X_train, dtype=torch.float32, device=device)
    y_train = torch.as_tensor(y_train, dtype=torch.float32, device=device)
    x_test = torch.as_tensor(x_test, dtype=torch.float32, device=device)
    y_test = torch.as_tensor(y_test, dtype=torch.float32, device=device)
    return X_train, y_train, x_test, y_test

# %%
class PrepareData(Dataset):

    def __init__(self, X, y):
        self.X = X
        self.y = y
        if not torch.is_tensor(X):
            self.X = torch.from_numpy(X)
        if not torch.is_tensor(y):
            self.y = torch.from_numpy(y)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

X_train, y_train, X_test, y_test = get_moon_data(n_samples=5000, noise=0.1)

train_dataset = PrepareData(X=X_train, y=y_train)
train_loader = DataLoader(train_dataset, batch_size=X_train.shape[0], shuffle=True)

test_dataset = PrepareData(X=X_test, y=y_test)
test_loader = DataLoader(test_dataset, batch_size=X_test.shape[0], shuffle=True)

# %%
#input is 2,500
#activation is relu
#2nd linear 500, 500
#activation is relu
#500, 2
#activation is sigmoid

#train, test and loss plots, epochs = 200


class MyNet(nn.Module):
  def __init__(self, hidden_dims, out_class):
    super().__init__()
    self.layer1 = nn.Linear(2, hidden_dims)
    self.relu = nn.ReLU()
    self.layer2 = nn.Linear(hidden_dims,hidden_dims)
    self.clf = nn.Linear(hidden_dims,out_class)
    self.sig = nn.Sigmoid()

  def forward(self, x):
    x = self.layer1(x)
    x = self.relu(x)
    x = self.layer2(x)
    x = self.relu(x)
    x = self.clf(x)
    x = self.sig(x)

    return x

# %%
# Out:
# MyNet(
#   (layer1): Linear(in_features=2, out_features=500, bias=True)
#   (relu): ReLU()
#   (layer2): Linear(in_features=500, out_features=500, bias=True)
#   (clf): Linear(in_features=500, out_features=2, bias=True)
#   (sig): Sigmoid()
# )

# %%
def evalModel(net, testloader):
  acc = 0.0
  count = 0
  start_time = time.time()
  device = 'gpu' if next(net.parameters()).is_cuda else 'cpu'
  net.eval()

  for iter, (x, y) in enumerate(testloader):
        count += x.shape[0]
        batch_x = Variable(x).float()
        batch_y = Variable(y).long()
        if device == 'gpu':
          batch_x = batch_x.cuda()
          batch_y = batch_y.cuda()
        outputs = net(batch_x)
        acc += torch.sum(outputs.max(1)[1]==batch_y)

  time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
  print('Accuracy: {:5f} | Time: {}'.format(acc/count,time_lapse))
  return acc/count

# %%
def trainModel(net, trainloader, train_option, testloader):
  loss_func = nn.CrossEntropyLoss()
  lr = train_option['lr']
  epoch = train_option['epoch']
  device = train_option['device'] if 'device' in train_option.keys() else 'cpu'
  log_iter = train_option['log_iter'] if 'log_iter' in train_option.keys() else 20
  eval_epoch = 1

  # optimizer = optim.SGD(net.parameters(), lr)
  optimizer = train_option['optim']

  start_time = time.time()
  if device == 'gpu':
    net = net.cuda()

  iters = 0
  running_loss = 0.0

  losses = []
  training_accs = []
  testing_accs = []

  for ep in range(epoch):
    net.train()
    acc = 0.0
    count = 0
    loss = 0
    for iter, (x, y) in enumerate(trainloader):
      iters += 1
      batch_x = Variable(x).float()
      batch_y = Variable(y).long()
      if device == 'gpu':
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()

      outputs = net(batch_x)
      loss = loss_func(outputs, batch_y)

      # print(outputs[0], outputs.max(1)[1][0])

      acc += torch.sum(outputs.max(1)[1]==batch_y)
      count += x.shape[0]

      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      running_loss += loss.item()
      loss += loss.item()

      time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
      if iter % log_iter == 0:
        print('Epoch:{:2d} | Iter:{:5d} | Time: {} | Train Loss: {:.4f} | Average Loss: {:.4f} '.format(ep+1, iter, time_lapse, loss.item(), running_loss/iters))

    if testloader is not None and ep % eval_epoch == 0:
      testing_accs.append(evalModel(net, testloader).item())
    else:
      testing_accs.append(0)

    losses.append(loss.item())
    training_accs.append((acc/count).item())

  return losses, training_accs, testing_accs

# %%
mynet = MyNet(100, 2)

print(mynet)
# Out:
# MyNet(
#   (layer1): Linear(in_features=2, out_features=100, bias=True)
#   (relu): ReLU()
#   (layer2): Linear(in_features=100, out_features=100, bias=True)
#   (clf): Linear(in_features=100, out_features=2, bias=True)
#   (sig): Sigmoid()
# )

# %%
train_option = {}
train_option['lr'] = 0.1
train_option['epoch'] = 200
train_option['device'] = 'cpu'
train_option['optim'] = optim.SGD(mynet.parameters(), 0.1)
losses_sgd, training_accs_sgd, testing_accs_sgd = trainModel(mynet, train_loader, train_option, test_loader)
mynet = MyNet(100, 2)
train_option['optim'] = optim.Adam(mynet.parameters(), 0.1)
losses_adam, training_accs_adam, testing_accs_adam = trainModel(mynet, train_loader, train_option, test_loader)
mynet = MyNet(100, 2)
train_option['optim'] = optim.Adagrad(mynet.parameters(), 0.1)
losses_adagrad, training_accs_adagrad, testing_accs_adagrad = trainModel(mynet, train_loader, train_option, test_loader)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3909 | Average Loss: 0.6955
# Accuracy: 0.326667 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3860 | Average Loss: 0.6942
# Accuracy: 0.467333 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3810 | Average Loss: 0.6930
# Accuracy: 0.522667 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3761 | Average Loss: 0.6918
# Accuracy: 0.578000 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3713 | Average Loss: 0.6905
# Accuracy: 0.631333 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3664 | Average Loss: 0.6893
# Accuracy: 0.678667 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3616 | Average Loss: 0.6881
# Accuracy: 0.732000 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3567 | Average Loss: 0.6869
# Accuracy: 0.761333 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3519 | Average Loss: 0.6857
# Accuracy: 0.778667 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3470 | Average Loss: 0.6845
# Accuracy: 0.790667 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3421 | Average Loss: 0.6832
# Accuracy: 0.798667 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3371 | Average Loss: 0.6820
# Accuracy: 0.808000 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3321 | Average Loss: 0.6808
# Accuracy: 0.812667 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3271 | Average Loss: 0.6795
# Accuracy: 0.816667 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3220 | Average Loss: 0.6783
# Accuracy: 0.820000 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3169 | Average Loss: 0.6771
# Accuracy: 0.823333 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3119 | Average Loss: 0.6758
# Accuracy: 0.824667 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3069 | Average Loss: 0.6746
# Accuracy: 0.826667 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3018 | Average Loss: 0.6733
# Accuracy: 0.828667 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2967 | Average Loss: 0.6721
# Accuracy: 0.831333 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2916 | Average Loss: 0.6708
# Accuracy: 0.830667 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2864 | Average Loss: 0.6696
# Accuracy: 0.831333 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2812 | Average Loss: 0.6683
# Accuracy: 0.832000 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2758 | Average Loss: 0.6671
# Accuracy: 0.832667 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2705 | Average Loss: 0.6658
# Accuracy: 0.833333 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2650 | Average Loss: 0.6645
# Accuracy: 0.834000 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2595 | Average Loss: 0.6632
# Accuracy: 0.834667 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2540 | Average Loss: 0.6619
# Accuracy: 0.834667 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2484 | Average Loss: 0.6606
# Accuracy: 0.835333 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2427 | Average Loss: 0.6593
# Accuracy: 0.835333 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2370 | Average Loss: 0.6580
# Accuracy: 0.836000 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2312 | Average Loss: 0.6567
# Accuracy: 0.836667 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2254 | Average Loss: 0.6553
# Accuracy: 0.837333 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2196 | Average Loss: 0.6540
# Accuracy: 0.838667 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2138 | Average Loss: 0.6527
# Accuracy: 0.838000 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2079 | Average Loss: 0.6513
# Accuracy: 0.838667 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.2020 | Average Loss: 0.6499
# Accuracy: 0.839333 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1961 | Average Loss: 0.6486
# Accuracy: 0.840000 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1902 | Average Loss: 0.6472
# Accuracy: 0.840000 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1843 | Average Loss: 0.6458
# Accuracy: 0.842000 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.1785 | Average Loss: 0.6444
# Accuracy: 0.842000 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1726 | Average Loss: 0.6431
# Accuracy: 0.844667 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1668 | Average Loss: 0.6417
# Accuracy: 0.844000 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1610 | Average Loss: 0.6403
# Accuracy: 0.843333 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1552 | Average Loss: 0.6389
# Accuracy: 0.843333 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1495 | Average Loss: 0.6375
# Accuracy: 0.843333 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1439 | Average Loss: 0.6361
# Accuracy: 0.843333 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1383 | Average Loss: 0.6347
# Accuracy: 0.844000 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1327 | Average Loss: 0.6333
# Accuracy: 0.844000 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1272 | Average Loss: 0.6319
# Accuracy: 0.844000 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1218 | Average Loss: 0.6305
# Accuracy: 0.844667 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.1164 | Average Loss: 0.6291
# Accuracy: 0.845333 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1112 | Average Loss: 0.6277
# Accuracy: 0.845333 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1059 | Average Loss: 0.6264
# Accuracy: 0.845333 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1008 | Average Loss: 0.6250
# Accuracy: 0.845333 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0958 | Average Loss: 0.6236
# Accuracy: 0.846000 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0908 | Average Loss: 0.6222
# Accuracy: 0.846000 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0860 | Average Loss: 0.6209
# Accuracy: 0.846000 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0812 | Average Loss: 0.6195
# Accuracy: 0.846667 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0765 | Average Loss: 0.6182
# Accuracy: 0.846667 | Time: 00:00:00
# Epoch:61 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0720 | Average Loss: 0.6168
# Accuracy: 0.846667 | Time: 00:00:00
# Epoch:62 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0675 | Average Loss: 0.6155
# Accuracy: 0.846667 | Time: 00:00:00
# Epoch:63 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0631 | Average Loss: 0.6141
# Accuracy: 0.846667 | Time: 00:00:00
# Epoch:64 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0588 | Average Loss: 0.6128
# Accuracy: 0.846667 | Time: 00:00:00
# Epoch:65 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0546 | Average Loss: 0.6115
# Accuracy: 0.846667 | Time: 00:00:00
# Epoch:66 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0505 | Average Loss: 0.6102
# Accuracy: 0.846667 | Time: 00:00:00
# Epoch:67 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0465 | Average Loss: 0.6089
# Accuracy: 0.846667 | Time: 00:00:00
# Epoch:68 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0426 | Average Loss: 0.6076
# Accuracy: 0.846667 | Time: 00:00:00
# Epoch:69 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0388 | Average Loss: 0.6063
# Accuracy: 0.846667 | Time: 00:00:00
# Epoch:70 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0350 | Average Loss: 0.6051
# Accuracy: 0.847333 | Time: 00:00:00
# Epoch:71 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0314 | Average Loss: 0.6038
# Accuracy: 0.848000 | Time: 00:00:00
# Epoch:72 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0279 | Average Loss: 0.6025
# Accuracy: 0.848000 | Time: 00:00:00
# Epoch:73 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0244 | Average Loss: 0.6013
# Accuracy: 0.848000 | Time: 00:00:00
# Epoch:74 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0210 | Average Loss: 0.6001
# Accuracy: 0.848667 | Time: 00:00:00
# Epoch:75 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0177 | Average Loss: 0.5989
# Accuracy: 0.849333 | Time: 00:00:00
# Epoch:76 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0145 | Average Loss: 0.5977
# Accuracy: 0.849333 | Time: 00:00:00
# Epoch:77 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0114 | Average Loss: 0.5965
# Accuracy: 0.849333 | Time: 00:00:00
# Epoch:78 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0084 | Average Loss: 0.5953
# Accuracy: 0.850000 | Time: 00:00:00
# Epoch:79 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0054 | Average Loss: 0.5941
# Accuracy: 0.852667 | Time: 00:00:00
# Epoch:80 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0025 | Average Loss: 0.5930
# Accuracy: 0.852667 | Time: 00:00:00
# Epoch:81 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.9997 | Average Loss: 0.5918
# Accuracy: 0.853333 | Time: 00:00:00
# Epoch:82 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.9969 | Average Loss: 0.5907
# Accuracy: 0.854667 | Time: 00:00:00
# Epoch:83 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.9942 | Average Loss: 0.5895
# Accuracy: 0.854667 | Time: 00:00:00
# Epoch:84 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.9916 | Average Loss: 0.5884
# Accuracy: 0.854667 | Time: 00:00:00
# Epoch:85 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9891 | Average Loss: 0.5873
# Accuracy: 0.855333 | Time: 00:00:00
# Epoch:86 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9866 | Average Loss: 0.5862
# Accuracy: 0.856000 | Time: 00:00:00
# Epoch:87 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9842 | Average Loss: 0.5851
# Accuracy: 0.856000 | Time: 00:00:00
# Epoch:88 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9818 | Average Loss: 0.5841
# Accuracy: 0.856000 | Time: 00:00:00
# Epoch:89 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9795 | Average Loss: 0.5830
# Accuracy: 0.856667 | Time: 00:00:00
# Epoch:90 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9772 | Average Loss: 0.5820
# Accuracy: 0.857333 | Time: 00:00:00
# Epoch:91 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9750 | Average Loss: 0.5809
# Accuracy: 0.858000 | Time: 00:00:00
# Epoch:92 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9729 | Average Loss: 0.5799
# Accuracy: 0.858000 | Time: 00:00:00
# Epoch:93 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9708 | Average Loss: 0.5789
# Accuracy: 0.858667 | Time: 00:00:00
# Epoch:94 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9687 | Average Loss: 0.5779
# Accuracy: 0.858667 | Time: 00:00:00
# Epoch:95 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9667 | Average Loss: 0.5769
# Accuracy: 0.858667 | Time: 00:00:00
# Epoch:96 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9647 | Average Loss: 0.5759
# Accuracy: 0.860000 | Time: 00:00:00
# Epoch:97 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9628 | Average Loss: 0.5749
# Accuracy: 0.860000 | Time: 00:00:00
# Epoch:98 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9609 | Average Loss: 0.5740
# Accuracy: 0.860000 | Time: 00:00:00
# Epoch:99 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9591 | Average Loss: 0.5730
# Accuracy: 0.860667 | Time: 00:00:00
# Epoch:100 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.9573 | Average Loss: 0.5721
# Accuracy: 0.860667 | Time: 00:00:00
# Epoch:101 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9556 | Average Loss: 0.5711
# Accuracy: 0.860667 | Time: 00:00:00
# Epoch:102 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9539 | Average Loss: 0.5702
# Accuracy: 0.860667 | Time: 00:00:00
# Epoch:103 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9522 | Average Loss: 0.5693
# Accuracy: 0.861333 | Time: 00:00:00
# Epoch:104 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9505 | Average Loss: 0.5684
# Accuracy: 0.861333 | Time: 00:00:00
# Epoch:105 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9489 | Average Loss: 0.5675
# Accuracy: 0.862000 | Time: 00:00:00
# Epoch:106 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9473 | Average Loss: 0.5666
# Accuracy: 0.862000 | Time: 00:00:00
# Epoch:107 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9458 | Average Loss: 0.5657
# Accuracy: 0.862000 | Time: 00:00:00
# Epoch:108 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9443 | Average Loss: 0.5649
# Accuracy: 0.862000 | Time: 00:00:00
# Epoch:109 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9428 | Average Loss: 0.5640
# Accuracy: 0.862000 | Time: 00:00:00
# Epoch:110 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9414 | Average Loss: 0.5632
# Accuracy: 0.862000 | Time: 00:00:00
# Epoch:111 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9399 | Average Loss: 0.5623
# Accuracy: 0.862000 | Time: 00:00:00
# Epoch:112 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9385 | Average Loss: 0.5615
# Accuracy: 0.862000 | Time: 00:00:00
# Epoch:113 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9372 | Average Loss: 0.5607
# Accuracy: 0.862000 | Time: 00:00:00
# Epoch:114 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9358 | Average Loss: 0.5599
# Accuracy: 0.862667 | Time: 00:00:00
# Epoch:115 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9345 | Average Loss: 0.5590
# Accuracy: 0.862667 | Time: 00:00:00
# Epoch:116 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9332 | Average Loss: 0.5583
# Accuracy: 0.862667 | Time: 00:00:00
# Epoch:117 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9320 | Average Loss: 0.5575
# Accuracy: 0.863333 | Time: 00:00:00
# Epoch:118 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9307 | Average Loss: 0.5567
# Accuracy: 0.863333 | Time: 00:00:00
# Epoch:119 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9295 | Average Loss: 0.5559
# Accuracy: 0.863333 | Time: 00:00:00
# Epoch:120 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9283 | Average Loss: 0.5551
# Accuracy: 0.863333 | Time: 00:00:00
# Epoch:121 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9271 | Average Loss: 0.5544
# Accuracy: 0.863333 | Time: 00:00:00
# Epoch:122 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9259 | Average Loss: 0.5536
# Accuracy: 0.863333 | Time: 00:00:00
# Epoch:123 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9248 | Average Loss: 0.5529
# Accuracy: 0.863333 | Time: 00:00:00
# Epoch:124 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9237 | Average Loss: 0.5522
# Accuracy: 0.863333 | Time: 00:00:00
# Epoch:125 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9226 | Average Loss: 0.5514
# Accuracy: 0.863333 | Time: 00:00:00
# Epoch:126 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9215 | Average Loss: 0.5507
# Accuracy: 0.864667 | Time: 00:00:00
# Epoch:127 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9204 | Average Loss: 0.5500
# Accuracy: 0.865333 | Time: 00:00:00
# Epoch:128 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9194 | Average Loss: 0.5493
# Accuracy: 0.866000 | Time: 00:00:00
# Epoch:129 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9184 | Average Loss: 0.5486
# Accuracy: 0.866000 | Time: 00:00:00
# Epoch:130 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9173 | Average Loss: 0.5479
# Accuracy: 0.866000 | Time: 00:00:00
# Epoch:131 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9163 | Average Loss: 0.5472
# Accuracy: 0.866000 | Time: 00:00:00
# Epoch:132 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9154 | Average Loss: 0.5465
# Accuracy: 0.866000 | Time: 00:00:00
# Epoch:133 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9144 | Average Loss: 0.5459
# Accuracy: 0.866000 | Time: 00:00:00
# Epoch:134 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9134 | Average Loss: 0.5452
# Accuracy: 0.867333 | Time: 00:00:00
# Epoch:135 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9125 | Average Loss: 0.5445
# Accuracy: 0.867333 | Time: 00:00:00
# Epoch:136 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9116 | Average Loss: 0.5439
# Accuracy: 0.867333 | Time: 00:00:00
# Epoch:137 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9107 | Average Loss: 0.5432
# Accuracy: 0.868000 | Time: 00:00:00
# Epoch:138 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9098 | Average Loss: 0.5426
# Accuracy: 0.868000 | Time: 00:00:00
# Epoch:139 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9089 | Average Loss: 0.5420
# Accuracy: 0.868000 | Time: 00:00:00
# Epoch:140 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9080 | Average Loss: 0.5413
# Accuracy: 0.868000 | Time: 00:00:00
# Epoch:141 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9072 | Average Loss: 0.5407
# Accuracy: 0.868000 | Time: 00:00:00
# Epoch:142 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9063 | Average Loss: 0.5401
# Accuracy: 0.868000 | Time: 00:00:00
# Epoch:143 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9055 | Average Loss: 0.5395
# Accuracy: 0.868667 | Time: 00:00:00
# Epoch:144 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9047 | Average Loss: 0.5389
# Accuracy: 0.870667 | Time: 00:00:00
# Epoch:145 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9039 | Average Loss: 0.5383
# Accuracy: 0.870667 | Time: 00:00:00
# Epoch:146 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.9031 | Average Loss: 0.5377
# Accuracy: 0.870667 | Time: 00:00:00
# Epoch:147 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.9023 | Average Loss: 0.5371
# Accuracy: 0.872000 | Time: 00:00:00
# Epoch:148 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.9015 | Average Loss: 0.5365
# Accuracy: 0.872667 | Time: 00:00:00
# Epoch:149 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.9008 | Average Loss: 0.5359
# Accuracy: 0.873333 | Time: 00:00:00
# Epoch:150 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.9000 | Average Loss: 0.5354
# Accuracy: 0.873333 | Time: 00:00:00
# Epoch:151 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8993 | Average Loss: 0.5348
# Accuracy: 0.874000 | Time: 00:00:00
# Epoch:152 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8985 | Average Loss: 0.5342
# Accuracy: 0.874000 | Time: 00:00:00
# Epoch:153 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8978 | Average Loss: 0.5337
# Accuracy: 0.874667 | Time: 00:00:00
# Epoch:154 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8971 | Average Loss: 0.5331
# Accuracy: 0.875333 | Time: 00:00:00
# Epoch:155 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8964 | Average Loss: 0.5326
# Accuracy: 0.876667 | Time: 00:00:00
# Epoch:156 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8957 | Average Loss: 0.5320
# Accuracy: 0.877333 | Time: 00:00:00
# Epoch:157 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8950 | Average Loss: 0.5315
# Accuracy: 0.877333 | Time: 00:00:00
# Epoch:158 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8943 | Average Loss: 0.5310
# Accuracy: 0.877333 | Time: 00:00:00
# Epoch:159 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8936 | Average Loss: 0.5304
# Accuracy: 0.878000 | Time: 00:00:00
# Epoch:160 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8930 | Average Loss: 0.5299
# Accuracy: 0.878000 | Time: 00:00:00
# Epoch:161 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.8923 | Average Loss: 0.5294
# Accuracy: 0.878667 | Time: 00:00:00
# Epoch:162 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8916 | Average Loss: 0.5289
# Accuracy: 0.879333 | Time: 00:00:00
# Epoch:163 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8910 | Average Loss: 0.5284
# Accuracy: 0.879333 | Time: 00:00:00
# Epoch:164 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8904 | Average Loss: 0.5279
# Accuracy: 0.879333 | Time: 00:00:00
# Epoch:165 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8897 | Average Loss: 0.5274
# Accuracy: 0.879333 | Time: 00:00:00
# Epoch:166 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8891 | Average Loss: 0.5269
# Accuracy: 0.879333 | Time: 00:00:00
# Epoch:167 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8885 | Average Loss: 0.5264
# Accuracy: 0.879333 | Time: 00:00:00
# Epoch:168 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8879 | Average Loss: 0.5259
# Accuracy: 0.879333 | Time: 00:00:00
# Epoch:169 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8873 | Average Loss: 0.5254
# Accuracy: 0.880000 | Time: 00:00:00
# Epoch:170 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8867 | Average Loss: 0.5249
# Accuracy: 0.880667 | Time: 00:00:00
# Epoch:171 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8861 | Average Loss: 0.5244
# Accuracy: 0.880667 | Time: 00:00:00
# Epoch:172 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8856 | Average Loss: 0.5239
# Accuracy: 0.880667 | Time: 00:00:00
# Epoch:173 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8850 | Average Loss: 0.5235
# Accuracy: 0.880667 | Time: 00:00:00
# Epoch:174 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8844 | Average Loss: 0.5230
# Accuracy: 0.881333 | Time: 00:00:00
# Epoch:175 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8839 | Average Loss: 0.5225
# Accuracy: 0.882000 | Time: 00:00:00
# Epoch:176 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.8833 | Average Loss: 0.5221
# Accuracy: 0.882667 | Time: 00:00:00
# Epoch:177 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8828 | Average Loss: 0.5216
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:178 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8822 | Average Loss: 0.5212
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:179 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8817 | Average Loss: 0.5207
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:180 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8811 | Average Loss: 0.5203
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:181 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8806 | Average Loss: 0.5198
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:182 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8801 | Average Loss: 0.5194
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:183 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8796 | Average Loss: 0.5190
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:184 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8791 | Average Loss: 0.5185
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:185 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8786 | Average Loss: 0.5181
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:186 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8781 | Average Loss: 0.5177
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:187 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8776 | Average Loss: 0.5173
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:188 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8771 | Average Loss: 0.5168
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:189 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8766 | Average Loss: 0.5164
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:190 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8761 | Average Loss: 0.5160
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:191 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8757 | Average Loss: 0.5156
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:192 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.8752 | Average Loss: 0.5152
# Accuracy: 0.883333 | Time: 00:00:00
# Epoch:193 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.8747 | Average Loss: 0.5148
# Accuracy: 0.884000 | Time: 00:00:00
# Epoch:194 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.8743 | Average Loss: 0.5144
# Accuracy: 0.884667 | Time: 00:00:00
# Epoch:195 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.8738 | Average Loss: 0.5140
# Accuracy: 0.885333 | Time: 00:00:00
# Epoch:196 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.8734 | Average Loss: 0.5136
# Accuracy: 0.885333 | Time: 00:00:00
# Epoch:197 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.8729 | Average Loss: 0.5132
# Accuracy: 0.886000 | Time: 00:00:00
# Epoch:198 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.8725 | Average Loss: 0.5128
# Accuracy: 0.886000 | Time: 00:00:00
# Epoch:199 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.8720 | Average Loss: 0.5124
# Accuracy: 0.887333 | Time: 00:00:00
# Epoch:200 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.8716 | Average Loss: 0.5121
# Accuracy: 0.887333 | Time: 00:00:00
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.4027 | Average Loss: 0.7013
# Accuracy: 0.764000 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.0739 | Average Loss: 0.6191
# Accuracy: 0.620000 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3089 | Average Loss: 0.6309
# Accuracy: 0.857333 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.9136 | Average Loss: 0.5874
# Accuracy: 0.872667 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8981 | Average Loss: 0.5597
# Accuracy: 0.890000 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8795 | Average Loss: 0.5397
# Accuracy: 0.898667 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8609 | Average Loss: 0.5241
# Accuracy: 0.904000 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8416 | Average Loss: 0.5112
# Accuracy: 0.909333 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8292 | Average Loss: 0.5005
# Accuracy: 0.912000 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8172 | Average Loss: 0.4913
# Accuracy: 0.911333 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8169 | Average Loss: 0.4837
# Accuracy: 0.917333 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8125 | Average Loss: 0.4773
# Accuracy: 0.920667 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8094 | Average Loss: 0.4717
# Accuracy: 0.924667 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8037 | Average Loss: 0.4667
# Accuracy: 0.928667 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.7959 | Average Loss: 0.4621
# Accuracy: 0.930667 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.7892 | Average Loss: 0.4579
# Accuracy: 0.929333 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7859 | Average Loss: 0.4541
# Accuracy: 0.930000 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7878 | Average Loss: 0.4507
# Accuracy: 0.934000 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7806 | Average Loss: 0.4476
# Accuracy: 0.938000 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7708 | Average Loss: 0.4445
# Accuracy: 0.942000 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7620 | Average Loss: 0.4414
# Accuracy: 0.943333 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7574 | Average Loss: 0.4386
# Accuracy: 0.945333 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7488 | Average Loss: 0.4358
# Accuracy: 0.949333 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7383 | Average Loss: 0.4330
# Accuracy: 0.953333 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7300 | Average Loss: 0.4303
# Accuracy: 0.958667 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7217 | Average Loss: 0.4276
# Accuracy: 0.966667 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7118 | Average Loss: 0.4250
# Accuracy: 0.969333 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7023 | Average Loss: 0.4223
# Accuracy: 0.972667 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.6894 | Average Loss: 0.4197
# Accuracy: 0.974667 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.6782 | Average Loss: 0.4170
# Accuracy: 0.983333 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.6652 | Average Loss: 0.4143
# Accuracy: 0.987333 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6522 | Average Loss: 0.4115
# Accuracy: 0.993333 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6386 | Average Loss: 0.4087
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6306 | Average Loss: 0.4060
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6306 | Average Loss: 0.4034
# Accuracy: 0.994667 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6334 | Average Loss: 0.4010
# Accuracy: 0.995333 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6295 | Average Loss: 0.3986
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6295 | Average Loss: 0.3964
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6285 | Average Loss: 0.3943
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6287 | Average Loss: 0.3923
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6290 | Average Loss: 0.3904
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6283 | Average Loss: 0.3886
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6286 | Average Loss: 0.3869
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6284 | Average Loss: 0.3852
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6280 | Average Loss: 0.3836
# Accuracy: 0.995333 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6282 | Average Loss: 0.3821
# Accuracy: 0.995333 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6281 | Average Loss: 0.3807
# Accuracy: 0.995333 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6279 | Average Loss: 0.3793
# Accuracy: 0.995333 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6277 | Average Loss: 0.3780
# Accuracy: 0.995333 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6277 | Average Loss: 0.3767
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6276 | Average Loss: 0.3754
# Accuracy: 0.995333 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6274 | Average Loss: 0.3743
# Accuracy: 0.995333 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6273 | Average Loss: 0.3731
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6273 | Average Loss: 0.3720
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6272 | Average Loss: 0.3709
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6271 | Average Loss: 0.3699
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6272 | Average Loss: 0.3689
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6272 | Average Loss: 0.3680
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6272 | Average Loss: 0.3671
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6271 | Average Loss: 0.3662
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:61 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.6271 | Average Loss: 0.3653
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:62 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3645
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:63 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3637
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:64 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3629
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:65 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3621
# Accuracy: 0.996000 | Time: 00:00:00
# Epoch:66 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3614
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:67 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3607
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:68 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3600
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:69 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3593
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:70 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3586
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:71 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3580
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:72 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3574
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:73 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3568
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:74 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3562
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:75 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6271 | Average Loss: 0.3556
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:76 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3551
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:77 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3545
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:78 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3540
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:79 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3535
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:80 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3530
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:81 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3525
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:82 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3521
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:83 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3516
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:84 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3511
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:85 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3507
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:86 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3503
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:87 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3498
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:88 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3494
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:89 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3490
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:90 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6271 | Average Loss: 0.3486
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:91 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3482
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:92 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3479
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:93 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3475
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:94 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3471
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:95 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3468
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:96 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3464
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:97 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3461
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:98 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3458
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:99 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3454
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:100 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3451
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:101 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3448
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:102 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3445
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:103 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3442
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:104 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3439
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:105 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3436
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:106 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3433
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:107 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6271 | Average Loss: 0.3431
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:108 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3428
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:109 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3425
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:110 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3423
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:111 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3420
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:112 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3417
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:113 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3415
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:114 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3412
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:115 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3410
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:116 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3408
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:117 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3405
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:118 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3403
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:119 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3401
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:120 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3399
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:121 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3396
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:122 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3394
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:123 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6271 | Average Loss: 0.3392
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:124 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3390
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:125 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3388
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:126 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3386
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:127 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3384
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:128 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3382
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:129 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3380
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:130 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3378
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:131 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3376
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:132 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3375
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:133 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3373
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:134 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3371
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:135 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3369
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:136 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3368
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:137 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3366
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:138 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3364
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:139 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6271 | Average Loss: 0.3363
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:140 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3361
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:141 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3359
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:142 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3358
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:143 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3356
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:144 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3355
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:145 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3353
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:146 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3352
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:147 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3350
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:148 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3349
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:149 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3347
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:150 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3346
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:151 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3345
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:152 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3343
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:153 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3342
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:154 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3341
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:155 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3339
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:156 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6271 | Average Loss: 0.3338
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:157 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3337
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:158 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3335
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:159 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3334
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:160 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3333
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:161 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3332
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:162 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3330
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:163 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3329
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:164 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3328
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:165 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3327
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:166 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3326
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:167 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3325
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:168 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3323
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:169 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3322
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:170 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3321
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:171 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3320
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:172 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3319
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:173 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6271 | Average Loss: 0.3318
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:174 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3317
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:175 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3316
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:176 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3315
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:177 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3314
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:178 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3313
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:179 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3312
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:180 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3311
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:181 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3310
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:182 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3309
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:183 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3308
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:184 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3307
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:185 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3306
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:186 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3305
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:187 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3304
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:188 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3303
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:189 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3303
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:190 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6271 | Average Loss: 0.3302
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:191 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6271 | Average Loss: 0.3301
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:192 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6271 | Average Loss: 0.3300
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:193 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6271 | Average Loss: 0.3299
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:194 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6271 | Average Loss: 0.3298
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:195 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6271 | Average Loss: 0.3297
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:196 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6271 | Average Loss: 0.3297
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:197 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6271 | Average Loss: 0.3296
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:198 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6271 | Average Loss: 0.3295
# Accuracy: 0.996667 | Time: 00:00:00
# ...
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:69 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6291 | Average Loss: 0.3626
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:70 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6290 | Average Loss: 0.3619
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:71 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6290 | Average Loss: 0.3612
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:72 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6290 | Average Loss: 0.3606
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:73 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6289 | Average Loss: 0.3599
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:74 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6289 | Average Loss: 0.3593
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:75 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6289 | Average Loss: 0.3587
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:76 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6288 | Average Loss: 0.3581
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:77 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6288 | Average Loss: 0.3576
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:78 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6288 | Average Loss: 0.3570
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:79 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6287 | Average Loss: 0.3565
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:80 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6287 | Average Loss: 0.3560
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:81 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6287 | Average Loss: 0.3554
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:82 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6286 | Average Loss: 0.3549
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:83 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6286 | Average Loss: 0.3545
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:84 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6286 | Average Loss: 0.3540
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:85 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6286 | Average Loss: 0.3535
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:86 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6286 | Average Loss: 0.3531
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:87 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6285 | Average Loss: 0.3526
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:88 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6285 | Average Loss: 0.3522
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:89 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6285 | Average Loss: 0.3517
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:90 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6285 | Average Loss: 0.3513
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:91 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6284 | Average Loss: 0.3509
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:92 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6284 | Average Loss: 0.3505
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:93 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6284 | Average Loss: 0.3501
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:94 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6284 | Average Loss: 0.3497
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:95 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6284 | Average Loss: 0.3494
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:96 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6284 | Average Loss: 0.3490
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:97 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6283 | Average Loss: 0.3486
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:98 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6283 | Average Loss: 0.3483
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:99 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6283 | Average Loss: 0.3480
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:100 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6283 | Average Loss: 0.3476
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:101 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6283 | Average Loss: 0.3473
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:102 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6283 | Average Loss: 0.3470
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:103 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6283 | Average Loss: 0.3466
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:104 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6282 | Average Loss: 0.3463
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:105 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6282 | Average Loss: 0.3460
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:106 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6282 | Average Loss: 0.3457
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:107 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6282 | Average Loss: 0.3454
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:108 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6282 | Average Loss: 0.3451
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:109 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6282 | Average Loss: 0.3448
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:110 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6282 | Average Loss: 0.3446
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:111 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6282 | Average Loss: 0.3443
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:112 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6281 | Average Loss: 0.3440
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:113 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6281 | Average Loss: 0.3438
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:114 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6281 | Average Loss: 0.3435
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:115 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6281 | Average Loss: 0.3432
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:116 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6281 | Average Loss: 0.3430
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:117 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6281 | Average Loss: 0.3427
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:118 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6281 | Average Loss: 0.3425
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:119 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6281 | Average Loss: 0.3423
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:120 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6281 | Average Loss: 0.3420
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:121 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6280 | Average Loss: 0.3418
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:122 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6280 | Average Loss: 0.3416
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:123 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6280 | Average Loss: 0.3413
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:124 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6280 | Average Loss: 0.3411
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:125 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6280 | Average Loss: 0.3409
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:126 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6280 | Average Loss: 0.3407
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:127 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6280 | Average Loss: 0.3405
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:128 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6280 | Average Loss: 0.3403
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:129 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6280 | Average Loss: 0.3401
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:130 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6280 | Average Loss: 0.3399
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:131 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6280 | Average Loss: 0.3397
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:132 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3395
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:133 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3393
# Accuracy: 0.996667 | Time: 00:00:00
# Epoch:134 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3391
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:135 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3389
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:136 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3387
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:137 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3385
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:138 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3384
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:139 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3382
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:140 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3380
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:141 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3378
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:142 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3377
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:143 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3375
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:144 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3374
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:145 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3372
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:146 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6279 | Average Loss: 0.3370
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:147 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6278 | Average Loss: 0.3369
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:148 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3367
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:149 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3366
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:150 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3364
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:151 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3363
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:152 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3361
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:153 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3360
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:154 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3358
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:155 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3357
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:156 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3355
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:157 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3354
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:158 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3353
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:159 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3351
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:160 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3350
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:161 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3349
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:162 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6278 | Average Loss: 0.3347
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:163 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6278 | Average Loss: 0.3346
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:164 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6278 | Average Loss: 0.3345
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:165 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3344
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:166 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3342
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:167 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3341
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:168 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3340
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:169 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3339
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:170 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3338
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:171 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3336
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:172 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3335
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:173 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3334
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:174 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3333
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:175 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3332
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:176 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3331
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:177 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3330
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:178 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6277 | Average Loss: 0.3329
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:179 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6277 | Average Loss: 0.3328
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:180 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6277 | Average Loss: 0.3327
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:181 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6277 | Average Loss: 0.3326
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:182 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6277 | Average Loss: 0.3324
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:183 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6277 | Average Loss: 0.3323
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:184 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6277 | Average Loss: 0.3322
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:185 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6277 | Average Loss: 0.3321
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:186 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6277 | Average Loss: 0.3320
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:187 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6277 | Average Loss: 0.3320
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:188 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6277 | Average Loss: 0.3319
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:189 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6277 | Average Loss: 0.3318
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:190 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6276 | Average Loss: 0.3317
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:191 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6276 | Average Loss: 0.3316
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:192 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6276 | Average Loss: 0.3315
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:193 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6276 | Average Loss: 0.3314
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:194 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6276 | Average Loss: 0.3313
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:195 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6276 | Average Loss: 0.3312
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:196 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6276 | Average Loss: 0.3311
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:197 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6276 | Average Loss: 0.3310
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:198 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6276 | Average Loss: 0.3309
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:199 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6276 | Average Loss: 0.3309
# Accuracy: 0.997333 | Time: 00:00:00
# Epoch:200 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.6276 | Average Loss: 0.3308
# Accuracy: 0.997333 | Time: 00:00:00

# %%
print(testing_accs[0])
# Out:
# 0.4866666793823242

# %%
fig, axs = plt.subplots(1,3, figsize= (12,4))

axs[0].plot(range(200), losses)
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Loss")
axs[0].set_title("Loss vs Epochs")

axs[1].plot(range(200), training_accs)
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Training Accuracies")
axs[1].set_title("Train Accuracies vs Epochs")

axs[2].plot(range(200), testing_accs)
axs[2].set_xlabel("Epochs")
axs[2].set_ylabel("Test Accuracies")
axs[2].set_title("Test Accuracies vs Epochs")

plt.tight_layout()

# %% [markdown]
# # ADMM

# %% [markdown]
# ## Data Loading

# %%
def get_moon_data_admm(n_samples=1000, noise=0.1):
    
    X, y = make_moons(n_samples=n_samples, noise=noise, random_state=42)
    
    # Categorical vector
    y_h = np.zeros((len(y), 2))
    for i in range(len_classes):
        class_vec = np.zeros(len_classes)
        class_vec[i] = 1
        y_h[np.where(y==i)] = class_vec
    
    # Train test split
    X_train, x_test, y_train, y_test = train_test_split(X, y_h, test_size=0.3, random_state=42)
    X_train = torch.as_tensor(X_train, dtype=torch.float32, device=device)
    y_train = torch.as_tensor(y_train, dtype=torch.float32, device=device)
    x_test = torch.as_tensor(x_test, dtype=torch.float32, device=device)
    y_test = torch.as_tensor(y_test, dtype=torch.float32, device=device)
    return X_train, y_train, x_test, y_test

# %% [markdown]
# ## Helpers

# %%
import torch
import numpy as np
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# return softmax
def cross_entropy_with_softmax(label, zl):
    prob = softmax(zl)
    imask =torch.eq(prob,0.0)
    prob = torch.where(imask,torch.tensor(1e-10,device=device),prob)
    loss = cross_entropy(label, prob)
    return loss
def softmax(x):
    exp =torch.exp(x)
    imask =torch.eq(exp,float("inf"))
    exp = torch.where(imask,torch.exp(torch.tensor(88.6,device=device)),exp)
    return exp/(torch.sum(exp,dim=0)+1e-10)
def cross_entropy(label, prob):
    loss = -torch.sum(label * torch.log(prob))
    return loss
#return the  relu function
def relu(x):
    # return torch.maximum(x, torch.tensor(0,device=device)) + (0.1)*torch.minimum(x, torch.tensor(0, device=device))
    
    tanh = (torch.exp(x)-torch.exp(-x))/(torch.exp(x)+torch.exp(-x))
    tanh = tanh.to(device)
    return tanh

def tanh(x):
    tanh = (torch.exp(x)-torch.exp(-x))/(torch.exp(x)+torch.exp(-x))
    tanh = tanh.to(device)
    return tanh
def leaky_relu(x):
    if(x > 0):
        return x
    else:
        return 0.1 * x
# return phi
def eq1(a, W_next, b_next, z_next, u_next,rho):
    temp = z_next - torch.matmul(W_next, a) - b_next+u_next/rho
    res = rho / 2 * torch.sum(temp * temp)
    return res
# return the derivative of phi with regard to a
def eq1_a(a, W_next, b_next, z_next, u_next,rho):
    res = rho * torch.matmul(torch.transpose(W_next,0,1), torch.matmul(W_next, a) + b_next - z_next-u_next/rho)
    return res
# return the derivative of phi with regard to W
def eq1_W(a, W_next, b_next, z_next, u_next,rho):
    temp = torch.matmul(W_next, a) + b_next - z_next-u_next/rho
    temp2 = torch.transpose(a,0,1)
    res = rho * torch.matmul(temp, temp2)
    return res
# return the derivative of phi with regard to b
def eq1_b(a, W_next, b_next, z_next,u_next, rho):
    res = torch.reshape(torch.mean(rho * (torch.matmul(W_next, a) + b_next - z_next-u_next/rho), dim=1),shape=(-1, 1))
    return res
# return the derivative of phi with regard to z
def eq1_z(a, W_next, b_next, z_next, u_next, rho):
    res = rho * (z_next - b_next - torch.matmul(W_next, a)+u_next/rho)
    return res
# return the quadratic approximation of W-subproblem
def P(W_new, theta, a_last, W, b, z, u,rho):
    temp = W_new - W
    res = eq1(a_last, W, b, z, u,rho) + torch.sum(eq1_W(a_last, W, b, z, u,rho) * temp) + torch.sum(theta * temp * temp) / 2
    return res
# return the quadratic approximation of a-subproblem
def Q(a_new, tau, a, W_next, b_next, z_next, u_next,v,z,rho):
    temp = a_new - a
    res = a_obj(a, W_next, b_next, z_next, u_next,v,z,rho) + torch.sum(a_obj_gradient(a, W_next, b_next, z_next, u_next,v,z,rho) * temp) + torch.sum(
        tau * temp * temp) / 2
    return res
# return the objective value of a-subproblem
def a_obj(a, W_next, b_next, z_next, u_next,v,z,rho):
    res=eq1(a, W_next, b_next, z_next, u_next,rho)+rho/2*torch.sum((a-relu(z)+v)*(a-relu(z)+v))
    return res
# return the gradient of a-subproblem
def a_obj_gradient(a, W_next, b_next, z_next, u_next,v,z,rho):
    res=eq1_a(a, W_next, b_next, z_next, u_next,rho)+rho*(a-relu(z)+v)
    return res
# return the result of W-subproblem
def update_W(a_last, b, z, W_old, u,rho,alpha=1):
    gradients = eq1_W(a_last, W_old, b, z, u,rho)
    gamma = 2
    zeta = W_old - gradients / alpha
    while (eq1(a_last, zeta, b, z, u,rho) > P(zeta, alpha, a_last, W_old, b, z, u,rho)):
        alpha = alpha * gamma
        zeta = W_old - gradients / alpha  # Learning rate decreases to 0, leading to infinity loop here.
    theta = alpha
    W = zeta
    return W
# return the result of b-subproblem
def update_b(a_last, W, z, b_old, u,rho):
    gradients = eq1_b(a_last, W, b_old, z, u,rho)
    res = b_old - gradients / rho
    return res
# return the objective value of z-subproblem
def z_obj(a_last, W, b, z, u,v,a,rho):
    f=(z-torch.matmul(W,a_last)-b+u/rho)*(z-torch.matmul(W,a_last)-b+u/rho)+(a-relu(z)+v)*(a-relu(z)+v)
    return f
# return the result of z-subproblem
def update_z(a_last, W, b, a, u,v,rho):
    z1=torch.matmul(W,a_last)+b-u/rho;
    z2=(z1+a+v)/2
    z1=torch.minimum(z1,torch.tensor(0))
    z2=torch.maximum(z2,torch.tensor(0))
    value1=z_obj(a_last, W, b, z1, u,v,a,rho)
    value2=z_obj(a_last, W, b, z2, u,v,a,rho)
    imask =torch.greater(value1,value2)
    z=torch.where(imask,z2,z1)
    return z
# return the result of z_L-subproblem by FISTA
def update_zl(a_last, W, b, label, zl_old, u,rho):
    fzl = 10e10
    MAX_ITER = 500
    zl = zl_old
    lamda = 1
    zeta = zl
    eta = 4
    TOLERANCE = 1e-3
    for i in range(MAX_ITER):
        fzl_old = fzl
        fzl = cross_entropy_with_softmax(label, zl)+rho/2*torch.sum((zl-torch.matmul(W,a_last)-b+u/rho)*(zl-torch.matmul(W,a_last)-b+u/rho))
        if abs(fzl - fzl_old) < TOLERANCE:
            break
        lamda_old = lamda
        lamda = (1 + np.sqrt(1 + 4 * lamda * lamda)) / 2
        gamma = (1 - lamda_old) / lamda
        gradients2 = (softmax(zl) - label)
        zeta_old = zeta
        zeta = (rho * (torch.matmul(W, a_last)+b-u/rho) + (zl - eta * gradients2) / eta) / (rho + 1 / eta)
        zl = (1 - gamma) * zeta + gamma * zeta_old
    return zl
# return the result of a-subproblem
def update_a(W_next, b_next, z_next, z, a_old, u_next,v,rho,t=1):
    gradient = a_obj_gradient(a_old, W_next, b_next, z_next, u_next, v,z,rho)
    eta = 2
    beta=a_old-gradient/t
    while (a_obj(beta, W_next, b_next, z_next, u_next,v,z,rho) > Q(beta, t, a_old, W_next, b_next, z_next, u_next,v,z,rho)):
        t = t * eta
        beta =a_old-gradient/t
    tau = t
    a = beta
    return a

# %% [markdown]
# ## Metric

# %%
def get_accuracy(W, b, X, y):
    nums = y.shape[1]
    z = []
    a = []
    for i in range(len(W)):
        if(i == 0):
            z.append(torch.matmul(W[i], X) + b[i])
        else:
            a.append(relu(z[-1]))
            z.append(torch.matmul(W[i], a[i-1]) + b[i])
    
    cost = cross_entropy_with_softmax(y, z[-1]) / nums
    actual = torch.argmax(y, dim=0)
    pred = torch.argmax(z[-1], dim=0)
    return (torch.sum(torch.eq(pred, actual)) / nums, cost)    


# return the value of the augmented Lagrangian
def objective(x_train, y_train, W, b, z, a, u, rho):
    r = []
    for i in range(len(W)):
        if(i==0):
            r.append(torch.sum((z[i] - torch.matmul(W[i], x_train) - b[i]) * (z[i] - torch.matmul(W[i], x_train) - b[i])))
        else:
            r.append(torch.sum((z[i] - torch.matmul(W[i], a[i-1]) - b[i]) * (z[i] - torch.matmul(W[i], a[i-1]) - b[i])))
    
    loss = cross_entropy_with_softmax(y_train, z[-1])
    
    obj = loss + torch.trace(torch.matmul(z[-1] - torch.matmul(W[-1], a[-1]) - b[-1], torch.transpose(u,0,1)))
    
    for i in range(len(r)):
        obj = obj + (rho/2)*r[i]
    cum = 0
    for i in range(len(a)):
        obj = obj + (rho/2)*torch.sum((a[i] - relu(z[i])) * (a[i] - relu(z[i])))
    return obj, loss

# %% [markdown]
# ## Model

# %%
class ADMMNet():

    def __init__(self, params):
       
        seed_num = 18
        torch.random.manual_seed(seed=seed_num)
        
        hidden_layers = params['layers']
        self.W = []
        self.b = []
        self.z = []
        self.a = []
        self.u = None
        self.n_layers = len(hidden_layers)
        
        self.train_acc = [0]
        self.test_acc = [0]
        self.train_cost = []
        self.test_cost = []
        self.objective_value = []
        
        for layer in hidden_layers:
            torch.random.manual_seed(seed=seed_num)
            self.W.append(torch.normal(size=layer, mean=0, std=0.1, device=device))
            torch.random.manual_seed(seed=seed_num)
            self.b.append(torch.normal(size=(layer[0], 1), mean=0, std=0.1, device=device))
        
    def initialize(self, x_train, label):
        for i in range(self.n_layers):
            if(i == self.n_layers-1):
                imask = torch.eq(label, 0)
                self.z.append(torch.where(imask, -torch.ones_like(label), torch.ones_like(label)))
            elif(i==0):             
                self.z.append(torch.matmul(self.W[i], x_train) + self.b[i])
                self.a.append(relu(self.z[-1]))
            else:
                self.z.append(torch.matmul(self.W[i], self.a[i-1]) + self.b[i])
                self.a.append(relu(self.z[-1]))

        self.u = torch.zeros(self.z[-1].shape, device=device)    
    
    
    def fit(self, hyper_params, x_train, y_train):
        
       
        
        ## Params
        rho = hyper_params["rho"]
        theta = hyper_params["theta"]
        tau = hyper_params["tau"]        
        num_iter = hyper_params["num_iter"]
        
        linear_r = np.ones(num_iter)
        self.objective_value = np.ones(num_iter)
        self.train_acc = np.zeros(num_iter+1)
        self.train_cost = np.ones(num_iter+1)
        self.test_acc = np.zeros(num_iter+1)
        self.test_cost = np.ones(num_iter)
        ## Backward
        (_, self.train_cost[0]) = get_accuracy(self.W, self.b, x_train, y_train)
        
        for j in range(num_iter):
            pre = time.time()
            for i in range(self.n_layers-1, -1, -1):
                if(i!=0):
                    if(i==self.n_layers-1):
                        self.z[i] = update_zl(self.a[i-1], self.W[i], self.b[i], y_train, self.z[i], self.u, rho)
                        self.b[i] = update_b(self.a[i-1], self.W[i], self.z[i], self.b[i], self.u, rho)
                        self.W[i] = update_W(self.a[i-1], self.b[i], self.z[i], self.W[i], self.u, rho, theta)
                        self.a[i-1] = update_a(self.W[i], self.b[i], self.z[i], self.z[i-1], self.a[i-1], self.u, 0, rho, tau)
                    else:
                        self.z[i] = update_z(self.a[i-1], self.W[i], self.b[i], self.a[i], 0, 0, rho)
                        self.b[i] = update_b(self.a[i-1], self.W[i], self.z[i], self.b[i], 0, rho)
                        self.W[i] = update_W(self.a[i-1], self.b[i], self.z[i], self.W[i], 0, rho, theta)
                        self.a[i-1] = update_a(self.W[i], self.b[i], self.z[i], self.z[i-1], self.a[i-1], 0, 0, rho, tau)

                else:
                    self.z[i] = update_z(x_train, self.W[i], self.b[i], self.a[i], 0, 0, rho)
                    self.b[i] = update_b(x_train, self.W[i], self.z[i], self.b[i], 0, rho)
                    self.W[i] = update_W(x_train, self.b[i], self.z[i], self.W[i], 0, rho, theta)
            
            ## Forward
            for i in range(self.n_layers):
                if(i==0):
                    self.W[i] = update_W(x_train, self.b[i], self.z[i], self.W[i], 0, rho, theta)
                    self.b[i] = update_b(x_train, self.W[i], self.z[i], self.b[i], 0, rho)
                    self.z[i] = update_z(x_train, self.W[i], self.b[i], self.a[i], 0, 0, rho)
                    self.a[i] = update_a(self.W[i+1], self.b[i+1], self.z[i+1], self.z[i], self.a[i], 0, 0, rho, tau)
                elif(i==self.n_layers-1):
                    self.W[i] = update_W(self.a[i-1], self.b[i], self.z[i], self.W[i], self.u, rho, theta)
                    self.b[i] = update_b(self.a[i-1], self.W[i], self.z[i], self.b[i], self.u, rho)
                    self.z[i] = update_zl(self.a[i-1], self.W[i], self.b[i], y_train, self.z[i], self.u, rho)
                else:
                    self.W[i] = update_W(self.a[i-1], self.b[i], self.z[i], self.W[i], 0, rho, theta)
                    self.b[i] = update_b(self.a[i-1], self.W[i], self.z[i], self.b[i], 0, rho)
                    self.z[i] = update_z(self.a[i-1], self.W[i], self.b[i], self.a[i], 0, 0, rho)
                    self.a[i] = update_a(self.W[i+1], self.b[i+1], self.z[i+1], self.z[i], self.a[i], self.u, 0, rho, tau)
                    

            self.u = self.u + rho * (self.z[-1] - torch.matmul(self.W[-1], self.a[-1]) - self.b[-1])
            r = []
            for i in range(self.n_layers):
                if(i == 0):
                    r.append(torch.sum((self.z[i] - torch.matmul(self.W[i], x_train) - self.b[i]) * (self.z[i] - torch.matmul(self.W[i], x_train) - self.b[i])))
                else:
                    r.append(torch.sum((self.z[i] - torch.matmul( self.W[i], self.a[i-1]) - self.b[i]) * (self.z[i] - torch.matmul(self.W[i], self.a[i-1]) - self.b[i])))

            linear_r[j] = r[-1]

            obj, loss = objective(x_train, y_train, self.W, self.b, self.z, self.a, self.u, rho)
            self.objective_value[j] = obj.cpu().numpy()
            (self.train_acc[j+1], self.train_cost[j+1]) = get_accuracy(self.W, self.b, x_train, y_train)
            (self.test_acc[j+1], self.test_cost[j]) = get_accuracy(self.W, self.b, x_test, y_test)
            
            print("Epoch: {} | Lagrangian Objective: {:.2f} | Train Loss: {:.2f} | Test loss: {:.2f} | Train accuracy: {:.2f} | Test Accuracy: {:.2f}".format(
                j+1, obj, self.train_cost[j], self.test_cost[j], self.train_acc[j], self.test_acc[j]
            ))
            print("=====================================================================================================================")

# %%
X_train, y_train, x_test, y_test = get_moon_data_admm(n_samples=5000, noise=0.1)
X_train =torch.transpose(X_train, 0, 1)
y_train = torch.transpose(y_train, 0, 1)
x_test = torch.transpose(x_test, 0, 1)
y_test = torch.transpose(y_test, 0, 1)

# %%
params = {
    "layers" : [(100, 2), (100, 100), (2, 100)],
}
net = ADMMNet(params)
net.initialize(X_train, y_train)
hyper_params = {
    'rho' : 1e-06,
    'tau' : 1e-03,
    'theta' : 1e-03,
    'num_iter': 200
}
net.fit(hyper_params, X_train, y_train)
# Out:
# Epoch: 1 | Lagrangian Objective: 0.22 | Train Loss: 0.89 | Test loss: 0.48 | Train accuracy: 0.00 | Test Accuracy: 0.00
# =====================================================================================================================
# Epoch: 2 | Lagrangian Objective: 0.20 | Train Loss: 0.52 | Test loss: 0.49 | Train accuracy: 0.80 | Test Accuracy: 0.82
# =====================================================================================================================
# Epoch: 3 | Lagrangian Objective: 0.15 | Train Loss: 0.52 | Test loss: 0.57 | Train accuracy: 0.84 | Test Accuracy: 0.85
# =====================================================================================================================
# Epoch: 4 | Lagrangian Objective: 0.08 | Train Loss: 0.60 | Test loss: 0.40 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 5 | Lagrangian Objective: 0.09 | Train Loss: 0.43 | Test loss: 0.38 | Train accuracy: 0.85 | Test Accuracy: 0.86
# =====================================================================================================================
# Epoch: 6 | Lagrangian Objective: 0.10 | Train Loss: 0.41 | Test loss: 0.33 | Train accuracy: 0.85 | Test Accuracy: 0.86
# =====================================================================================================================
# Epoch: 7 | Lagrangian Objective: 0.10 | Train Loss: 0.36 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 8 | Lagrangian Objective: 0.10 | Train Loss: 0.34 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 9 | Lagrangian Objective: 0.10 | Train Loss: 0.36 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 10 | Lagrangian Objective: 0.10 | Train Loss: 0.37 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 11 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 12 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 13 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 14 | Lagrangian Objective: 0.10 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 15 | Lagrangian Objective: 0.10 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 16 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 17 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 18 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 19 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 20 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 21 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 22 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 23 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 24 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 25 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 26 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 27 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 28 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 29 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 30 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 31 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 32 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 33 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 34 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 35 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 36 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 37 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 38 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 39 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 40 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 41 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 42 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 43 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 44 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 45 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 46 | Lagrangian Objective: 0.09 | Train Loss: 0.32 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 47 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 48 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 49 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 50 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 51 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 52 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 53 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 54 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 55 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 56 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 57 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 58 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 59 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 60 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 61 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 62 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 63 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.30 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 64 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 65 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 66 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 67 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 68 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 69 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 70 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.88 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 71 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 72 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 73 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 74 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 75 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 76 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 77 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 78 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 79 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 80 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 81 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 82 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 83 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 84 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 85 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 86 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 87 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 88 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 89 | Lagrangian Objective: 0.09 | Train Loss: 0.33 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 90 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 91 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 92 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 93 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 94 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 95 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 96 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 97 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 98 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 99 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 100 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.89
# =====================================================================================================================
# Epoch: 101 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 102 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 103 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 104 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 105 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 106 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 107 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 108 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 109 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.31 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 110 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 111 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 112 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 113 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 114 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 115 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 116 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 117 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 118 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 119 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 120 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 121 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 122 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 123 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 124 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 125 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 126 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 127 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 128 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 129 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 130 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 131 | Lagrangian Objective: 0.09 | Train Loss: 0.34 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 132 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 133 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 134 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 135 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 136 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 137 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 138 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 139 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 140 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 141 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 142 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 143 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 144 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 145 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 146 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 147 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 148 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 149 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 150 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 151 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 152 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.32 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 153 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 154 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 155 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 156 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 157 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 158 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 159 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 160 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 161 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 162 | Lagrangian Objective: 0.09 | Train Loss: 0.35 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 163 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 164 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 165 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 166 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 167 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 168 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 169 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 170 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 171 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 172 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 173 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 174 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 175 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 176 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.88
# =====================================================================================================================
# Epoch: 177 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 178 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 179 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 180 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 181 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 182 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 183 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 184 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.33 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 185 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 186 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 187 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 188 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 189 | Lagrangian Objective: 0.09 | Train Loss: 0.36 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 190 | Lagrangian Objective: 0.09 | Train Loss: 0.37 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 191 | Lagrangian Objective: 0.09 | Train Loss: 0.37 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 192 | Lagrangian Objective: 0.09 | Train Loss: 0.37 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 193 | Lagrangian Objective: 0.09 | Train Loss: 0.37 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 194 | Lagrangian Objective: 0.09 | Train Loss: 0.37 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 195 | Lagrangian Objective: 0.09 | Train Loss: 0.37 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 196 | Lagrangian Objective: 0.09 | Train Loss: 0.37 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 197 | Lagrangian Objective: 0.09 | Train Loss: 0.37 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 198 | Lagrangian Objective: 0.09 | Train Loss: 0.37 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 199 | Lagrangian Objective: 0.09 | Train Loss: 0.37 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================
# Epoch: 200 | Lagrangian Objective: 0.09 | Train Loss: 0.37 | Test loss: 0.34 | Train accuracy: 0.87 | Test Accuracy: 0.87
# =====================================================================================================================

# %%
net.train_cost[0]
a1 = net.train_acc
a2 = net.test_acc
a3 = net.train_cost

# %%
plt.plot(net.train_acc, 'r', label = 'Tanh')
plt.scatter(np.arange(1, 201, 19), net.train_acc[::20], c='r', s=30)

plt.plot(a1, 'b', label='ReLu')
plt.scatter(np.arange(1, 201, 19), np.array(a1[::20]), c='b', s=30)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Test Accuracy', fontsize=16)
plt.title('Test Accuracy vs Epochs', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

# %%
plt.plot(net.test_acc, 'r', label = 'Tanh')
plt.scatter(np.arange(1, 201, 19), net.test_acc[::20], c='r', s=30)

plt.plot(a2, 'b', label='ReLu')
plt.scatter(np.arange(1, 201, 19), np.array(a2[::20]), c='b', s=30)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Test Accuracy', fontsize=16)
plt.title('Test Accuracy vs Epochs', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

# %%
plt.plot(net.train_cost, 'r', label = 'Tanh')
plt.scatter(np.arange(1, 201, 19), net.train_cost[::20], c='r', s=30)

plt.plot(a3, 'b', label='ReLu')
plt.scatter(np.arange(1, 201, 19), np.array(a3[::20]), c='b', s=30)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Loss vs Epochs', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

# %%
plt.plot(net.train_acc, 'r', label = 'ADMM')
plt.scatter(np.arange(1, 201, 19), net.train_acc[::20], c='r', s=30)

plt.plot(training_accs_sgd, 'b', label='SGD')
plt.scatter(np.arange(1, 201, 19), np.array(training_accs_sgd[::19]), c='b', s=30)

plt.plot(training_accs_adagrad, 'g', label='Adagrad')
plt.scatter(np.arange(1, 201, 19), np.array(training_accs_adagrad[::19]), c='g', s=30)

plt.plot(training_accs_adam, 'y', label='Adam')
plt.scatter(np.arange(1, 201, 20), np.array(training_accs_adam[::20]), c='y', s=30)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Train Accuracy', fontsize=16)
plt.title('Train Accuracy vs Epochs', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

# %%
xx = np.arange(1, 201, 19)
print(xx.shape)
print(len(np.array(losses_sgd[::19])))
print(type(net.train_cost[::20]))
# Out:
# (11,)
# 11
# <class 'numpy.ndarray'>

# %%
plt.plot(net.train_cost, 'r', label = 'ADMM')
plt.scatter(np.arange(1, 201, 19), net.train_cost[::20], c='r', s=30)
plt.plot(losses_sgd, 'b', label='SGD')
plt.scatter(np.arange(1, 201, 19), np.array(losses_sgd[::19]), c='b', s=30)
plt.plot(losses_adagrad, 'g', label='Adagrad')
plt.scatter(np.arange(1, 201, 19), np.array(losses_adagrad[::19]), c='g', s=30)
plt.plot(losses_adam, 'y', label='Adam')
plt.scatter(np.arange(1, 201, 20), np.array(losses_adam[::20]), c='y', s=30)
plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)
plt.title('Loss vs Epochs', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

# %%
plt.plot(net.test_acc, 'r', label = 'ADMM')
plt.scatter(np.arange(1, 201, 19), net.test_acc[::20], c='r', s=30)
plt.plot(testing_accs_sgd, 'b', label='SGD')
plt.scatter(np.arange(1, 201, 19), np.array(testing_accs_sgd[::19]), c='b', s=30)

plt.plot(testing_accs_adagrad, 'g', label='Adagrad')
plt.scatter(np.arange(1, 201, 19), np.array(testing_accs_adagrad[::19]), c='g', s=30)

plt.plot(testing_accs_adam, 'y', label='Adam')
plt.scatter(np.arange(1, 201, 20), np.array(testing_accs_adam[::20]), c='y', s=30)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Test accuracy', fontsize=16)
plt.title('Test Accuracy vs Epochs', fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.legend(fontsize=16)

# %%
plt.plot(net.objective_value)
